# %%
from utils import loaders,model_fun
from torch.utils.data import DataLoader
import torch

train_set=loaders.CostumImFolder(["./data/anime/train_img/"],
                                 ["./data/anime/train_label/"])
train_loader=DataLoader(train_set, batch_size=2, shuffle=True)

# %%
for in_img,tgt_stick,cc,dd in train_loader:
    print(in_img,tgt_stick)
# Out:
#   File "<ipython-input-7-102f37e00fe0>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
big_model=model_fun.Pix2PixHDModel(70+25+21+21+1,3,[])

# %%
#A=zip(train_set.samples_img,train_set.target)
#for aa,bb in A:
#    print(aa,bb)

# %%
for in_img,tgt_stick,cc,dd in train_loader:
    break

# %%
tgt_stick.shape
# Out:
# torch.Size([2, 1, 512, 512])

# %%
tgt_stick.max()
# Out:
# tensor(28., dtype=torch.float64)

# %%
big_model.forward(tgt_stick, 0,in_img, 0, infer=True)
# Out:
# torch.Size([2, 138, 512, 512]) cpu <class 'torch.Tensor'>
# torch.Size([2, 3, 512, 512]) cpu <class 'torch.Tensor'>
# torch.Size([2, 138, 512, 512]) cpu <class 'torch.Tensor'>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-41c563dd8ce7> in <module>
# ----> 1 big_model.forward(tgt_stick, 0,in_img, 0, infer=True)
#
# /project/at091-project-group18/dance_now/utils/model_fun.py in forward(self, label, inst, image, feat, infer)
#     501         # Fake Detection and Loss
#     502         pred_fake_pool = self.discriminate(input_label, fake_image, use_pool=True)
# --> 503         loss_D_fake = self.criterionGAN(pred_fake_pool, False)
#     504
#     505         # Real Detection and Loss
#
# /project/at091-project-group18/dance_now/utils/model_fun.py in discriminate(self, input_label, test_image, use_pool)
# ...

# %%
losses, generated = big_model(tgt_stick.cuda(), 0,in_img.cuda(), 0, infer=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-cf2054972e23> in <module>
# ----> 1 losses, generated = big_model(tgt_stick.cuda(), 0,in_img.cuda(), 0, infer=True)
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /project/at091-project-group18/dance_now/utils/model_fun.py in forward(self, label, inst, image, feat, infer)
#     478         else:
#     479             input_concat = input_label
# --> 480         fake_image = self.netG.forward(input_concat)
#     481
#     482         # Fake Detection and Loss
#
# ...

# %%
tgt_stick.shape
# Out:
# torch.Size([2, 1, 512, 512])

# %%
import functools

# %%
tgt_stick.shape

# %%
import matplotlib.pyplot as plt
plt.imshow(in_img.numpy().transpose(0,2,3,1)[0,...,0]+tgt_stick.numpy()[0,0,...]/tgt_stick.numpy().max())
plt.show()

# %%
print(train_set.transform)
print(train_set.target_transform)

# %%
import torch
import torch.nn as nn
torch.cuda.empty_cache()
criterion = nn.MSELoss()
G=model_fun.GlobalGenerator(input_nc=137,output_nc=3,n_blocks=5).cuda()
opt_G = torch.optim.Adam(G.parameters(), lr=1e-5, betas=(0.5, 0.999))
model_fun.weights_init(G)
G.train()
# Out:
# GlobalGenerator(
#   (model): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (11): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace)
#     (13): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
# ...

# %%
train_loader.__len__()
# Out:
# 5053

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-652c9523b019> in <module>
# ----> 1 for in_img,tgt_stick,cc,dd in train_loader:
#       2     break
#
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# ...

# %%
import tqdm
import matplotlib.pyplot as plt
for epoch in  tqdm.tqdm(range(10)) :
    for in_img,tgt_stick,cc,dd in train_loader:
        torch.cuda.empty_cache()
        out_stick=G(in_img.cuda())
        torch.cuda.empty_cache()

        # optimizer

        loss_G = criterion(out_stick,tgt_stick.cuda())

        G.zero_grad()
        loss_G.backward()
        opt_G.step()
        break
#    print(f"epoch {epoch} over, loss= {loss_G}")
#    plt.figure(figsize=(20,40))
#    plt.subplot(1,3,1)
#    plt.imshow(in_img[0,...].detach().cpu().numpy().transpose(1,2,0))
#    plt.subplot(1,3,2)
#    plt.imshow(tgt_stick[0,...].detach().cpu().numpy().transpose(1,2,0))
#    plt.subplot(1,3,3)
#    plt.imshow(y[0,...].detach().cpu().numpy().transpose(1,2,0))
#    plt.show()
    print(out_stick.shape)
    print(in_img.shape)
    print(tgt_stick.shape)
# Out:
#  10%|█         | 1/10 [00:03<00:34,  3.86s/it]
# torch.Size([2, 137, 512, 512])
# torch.Size([2, 3, 512, 512])
# torch.Size([2, 137, 512, 512])
#  20%|██        | 2/10 [00:07<00:30,  3.83s/it]
# torch.Size([2, 137, 512, 512])
# torch.Size([2, 3, 512, 512])
# torch.Size([2, 137, 512, 512])
#  30%|███       | 3/10 [00:11<00:26,  3.82s/it]
# torch.Size([2, 137, 512, 512])
# torch.Size([2, 3, 512, 512])
# torch.Size([2, 137, 512, 512])
#  40%|████      | 4/10 [00:15<00:22,  3.81s/it]
# torch.Size([2, 137, 512, 512])
# torch.Size([2, 3, 512, 512])
# torch.Size([2, 137, 512, 512])
#  50%|█████     | 5/10 [00:18<00:18,  3.80s/it]
# torch.Size([2, 137, 512, 512])
# torch.Size([2, 3, 512, 512])
# torch.Size([2, 137, 512, 512])
#  60%|██████    | 6/10 [00:22<00:15,  3.79s/it]
# torch.Size([2, 137, 512, 512])
# torch.Size([2, 3, 512, 512])
# torch.Size([2, 137, 512, 512])
#  70%|███████   | 7/10 [00:26<00:11,  3.78s/it]
# torch.Size([2, 137, 512, 512])
# torch.Size([2, 3, 512, 512])
# ...

# %%
del loss_G
torch.cuda.empty_cache()

# %%
G = model_fun.GlobalGenerator(input_nc=3,output_nc=3,n_blocks=5).cuda()
G.load_state_dict(torch.load("skeleton_model_9.pt"))
G.eval()
# Out:
# GlobalGenerator(
#   (model): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (11): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace)
#     (13): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
# ...

# %%
y=G(in_img.cuda())

# %%
import matplotlib.pyplot as plt
plt.imshow(in_img.numpy().transpose(0,2,3,1)[0,...])
plt.show()
plt.imshow(y.cpu().detach().numpy().transpose(0,2,3,1)[0,...])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.imshow(in_img.numpy().transpose(0,2,3,1)[0,...,0]+tgt_stick.numpy().transpose(0,2,3,1)[0,...].max(2))
plt.show()
plt.imshow(out_stick.cpu().detach().numpy().transpose(0,2,3,1)[0,...].max(2))
plt.show()

# %%
import matplotlib.pyplot as plt
plt.imshow(in_img.numpy().transpose(0,2,3,1)[0,...,0]+tgt_stick.numpy().transpose(0,2,3,1)[0,...].max(2))
plt.show()
plt.imshow(out_stick.cpu().detach().numpy().transpose(0,2,3,1)[0,...].max(2))
plt.show()

# %%
torch.save(G.state_dict(), "./skeleton_model.pt")

# %%
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
LABEL_NC=21
DATA_TYPE=32
NO_INSTANCE=True
USE_FEATURES=True
LOAD_FEATURES=False
LABEL_FEAT=False
def get_edges(t):
        edge = torch.cuda.ByteTensor(t.size()).zero_()
        edge[:,:,:,1:] = edge[:,:,:,1:] | (t[:,:,:,1:] != t[:,:,:,:-1])
        edge[:,:,:,:-1] = edge[:,:,:,:-1] | (t[:,:,:,1:] != t[:,:,:,:-1])
        edge[:,:,1:,:] = edge[:,:,1:,:] | (t[:,:,1:,:] != t[:,:,:-1,:])
        edge[:,:,:-1,:] = edge[:,:,:-1,:] | (t[:,:,1:,:] != t[:,:,:-1,:])
        if DATA_TYPE==16:
            return edge.half()
        else:
            return edge.float()
        
def encode_input(label_map, inst_map=None, real_image=None, feat_map=None, infer=False):             
    if LABEL_NC == 0:
        input_label = label_map.data.cuda()
    else:
        # create one-hot vector for label map 
        size = label_map.size()
        oneHot_size = (size[0], LABEL_NC, size[2], size[3])
        input_label = torch.cuda.FloatTensor(torch.Size(oneHot_size)).zero_()
        input_label = input_label.scatter_(1, label_map.data.long().cuda(), 1.0)
        if DATA_TYPE == 16:
            input_label = input_label.half()

    # get edges from instance map
    if not NO_INSTANCE:
        inst_map = inst_map.data.cuda()
        edge_map = get_edges(inst_map)
        input_label = torch.cat((input_label, edge_map), dim=1)         
    input_label = Variable(input_label, volatile=infer)

    # real images for training
    if real_image is not None:
        real_image = Variable(real_image.data.cuda())

    # instance map for feature encoding
    if USE_FEATURES:
        # get precomputed feature maps
        if LOAD_FEATURES:
            feat_map = Variable(feat_map.data.cuda())
        if LABEL_FEAT:
            inst_map = label_map.cuda()

    return input_label, inst_map, real_image, feat_map

# %%
input_label, inst_map, real_image, feat_map=encode_input(bb)

# %%
input_label.cpu().numpy()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-0c78bcf860b9> in <module>
# ----> 1 input_label.cpu().numpy()
#
# RuntimeError: CUDA error: device-side assert triggered

# %%
for ii in range(21):
    plt.subplot(5,5,ii+1)
    plt.imshow(input_label[0,ii,...].detach().cpu())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-55b5fb33d8ab> in <module>
#       1 for ii in range(21):
#       2     plt.subplot(5,5,ii+1)
# ----> 3     plt.imshow(input_label[0,ii,...].detach().cpu())
#
# RuntimeError: CUDA error: device-side assert triggered
