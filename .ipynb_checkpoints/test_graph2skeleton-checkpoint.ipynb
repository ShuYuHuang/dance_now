# %%
from utils import loaders,model_fun
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.autograd import Variable
import torch
import numpy as np
#-------------------------------------Loader Building---------------------------------

train_set=loaders.CostumImFolder(["./data/anime/train_img/"],
                                 ["./data/anime/train_label/"])
train_loader=DataLoader(train_set, batch_size=8, shuffle=True)

print(train_set.transform)
print(train_set.target_transform)

#-------------------------------------Model Building---------------------------------
GPU_ID=[0]
# Out:
# img_1_1-checkpoint.png not imported
# Compose(
#     Resize(size=(512, 512), interpolation=PIL.Image.BILINEAR)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#     Lambda()
# )
# None

# %%
torch.cuda.empty_cache()
big_model=model_fun.Pix2PixHDModel(28+1,3,GPU_ID)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-577bd14999ef> in <module>
#       1 torch.cuda.empty_cache()
# ----> 2 big_model=model_fun.Pix2PixHDModel(28+1,3,GPU_ID)
#
# /project/at091-project-group18/dance_now/utils/model_fun.py in __init__(self, label_nc, output_nc, gpu_ids)
#     346         self.netG = GlobalGenerator(netG_input_nc, output_nc, norm_layer=norm_layer)
#     347         if len(self.gpu_ids) > 0:
# --> 348             assert(torch.cuda.is_available())
#     349             self.netG.cuda(self.gpu_ids[0])
#     350
#
# AssertionError:

# %%
for in_img,tgt_stick,cc,dd in train_loader:
    break

# %%
big_model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8598da9432f7> in <module>
# ----> 1 big_model
#
# NameError: name 'big_model' is not defined

# %%
losses, out_img = big_model(Variable(tgt_stick).cuda(GPU_ID[0]), Variable(torch.tensor(0)).cuda(GPU_ID[0]), 
            Variable(in_img).cuda(GPU_ID[0]), Variable(torch.tensor(0)).cuda(GPU_ID[0]), infer=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1d074281b567> in <module>
# ----> 1 losses, out_img = big_model(Variable(tgt_stick).cuda(GPU_ID[0]), Variable(torch.tensor(0)).cuda(GPU_ID[0]),
#       2             Variable(in_img).cuda(GPU_ID[0]), Variable(torch.tensor(0)).cuda(GPU_ID[0]), infer=False)
#
# NameError: name 'big_model' is not defined

# %%
for aa,bb,cc,dd in train_loader:
    break

# %%
EDG=get_edges(bb.cuda())

# %%
EDG[0].shape
C=EDG[0].detach().cpu().numpy().transpose(1,2,0)
C.shape
# Out:
# (256, 512, 3)

# %%
plt.imshow(EDG[0].detach().cpu().numpy().transpose(1,2,0))

# %%
import torch.nn as nn
LABEL_NC=0
DATA_TYPE=32
NO_INSTANCE=True
USE_FEATURES=True
LOAD_FEATURES=False
LABEL_FEAT=False
def get_edges(t):
        edge = torch.cuda.ByteTensor(t.size()).zero_()
        edge[:,:,:,1:] = edge[:,:,:,1:] | (t[:,:,:,1:] != t[:,:,:,:-1])
        edge[:,:,:,:-1] = edge[:,:,:,:-1] | (t[:,:,:,1:] != t[:,:,:,:-1])
        edge[:,:,1:,:] = edge[:,:,1:,:] | (t[:,:,1:,:] != t[:,:,:-1,:])
        edge[:,:,:-1,:] = edge[:,:,:-1,:] | (t[:,:,1:,:] != t[:,:,:-1,:])
        if DATA_TYPE==16:
            return edge.half()
        else:
            return edge.float()
        
def encode_input(label_map, inst_map=None, real_image=None, feat_map=None, infer=False):             
    if LABEL_NC == 0:
        input_label = label_map.data.cuda()
    else:
        # create one-hot vector for label map 
        size = label_map.size()
        oneHot_size = (size[0], LABEL_NC, size[2], size[3])
        input_label = torch.cuda.FloatTensor(torch.Size(oneHot_size)).zero_()
        input_label = input_label.scatter_(1, label_map.data.long().cuda(), 1.0)
        if DATA_TYPE == 16:
            input_label = input_label.half()

    # get edges from instance map
    if not NO_INSTANCE:
        inst_map = inst_map.data.cuda()
        edge_map = get_edges(inst_map)
        input_label = torch.cat((input_label, edge_map), dim=1)         
    input_label = Variable(input_label, volatile=infer)

    # real images for training
    if real_image is not None:
        real_image = Variable(real_image.data.cuda())

    # instance map for feature encoding
    if USE_FEATURES:
        # get precomputed feature maps
        if LOAD_FEATURES:
            feat_map = Variable(feat_map.data.cuda())
        if LABEL_FEAT:
            inst_map = label_map.cuda()

    return input_label, inst_map, real_image, feat_map

# %%
input_label, inst_map, real_image, feat_map=encode_input(bb.sum(1).unsqueeze(1))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-41-714fdfa6b03b> in <module>
# ----> 1 input_label, inst_map, real_image, feat_map=encode_input(bb.sum(1).unsqueeze(1))
#
# <ipython-input-31-a8cac74e9c21> in encode_input(label_map, inst_map, real_image, feat_map, infer)
#      24         size = label_map.size()
#      25         oneHot_size = (size[0], LABEL_NC, size[2], size[3])
# ---> 26         input_label = torch.cuda.FloatTensor(torch.Size(oneHot_size)).zero_()
#      27         input_label = input_label.scatter_(1, label_map.data.long().cuda(), 1.0)
#      28         if DATA_TYPE == 16:
#
# RuntimeError: CUDA error: device-side assert triggered

# %%
print(bb.shape)
print(bb.max(),bb.min())
# Out:
# torch.Size([10, 3, 256, 512])
# tensor(255.) tensor(0.)

# %%
cc=bb.max(1).values.unsqueeze(1)

# %%
cc.shape
# Out:
# torch.Size([10, 1, 256, 512])

# %%
B=bb.view(10,3,256*512)

# %%
B=bb.detach().transpose(1,3).contiguous().view(10*256*512,3).numpy().copy()
print(B.shape)
print(B.max())
# Out:
# (1310720, 3)
# 255.0

# %%
import numpy as np
V=(B!=255).any(1)
M=np.intc(B[V,:])
M.shape
# Out:
# (25023, 3)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
Axes3D.scatter(ax,xs=M[:,0],ys= M[:,1], zs=M[:,2],alpha=0.1,s=1)

# %%
import numpy as np
M=np.intc(np.sort(M,axis=0))

# %%
cc.shape
# Out:
# (256, 512, 3)

# %%
cc=bb[0,...].detach().numpy().copy().transpose(1,2,0)

plt.imshow(np.intc(cc))

# %%
bb.max(1).values.shape
# Out:
# torch.Size([10, 256, 512])

# %%
dd=(bb/(bb.max(1).values).unsqueeze(1))[0].detach().numpy().copy().transpose(1,2,0)
plt.imshow(dd)

# %%
for ii in range(21):
    plt.subplot(5,5,ii+1)
    plt.imshow(input_label[0,ii,...].detach().cpu())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-55b5fb33d8ab> in <module>
#       1 for ii in range(21):
#       2     plt.subplot(5,5,ii+1)
# ----> 3     plt.imshow(input_label[0,ii,...].detach().cpu())
#
# NameError: name 'input_label' is not defined
