# %%
import sys
from pathlib import Path
sys.path.append(str(Path("../")))
from utils import create_head
import torch
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %%
NUM_GPU=torch.cuda.device_count()
head_dataset=create_head.create(["../data/soldier/train_img/"],
                                 ["../data/soldier/train_label/"],
                               "../data/soldier/train_headimg/")
head_loader=DataLoader(head_dataset, batch_size=8,\
                        shuffle=False,num_workers = 4*NUM_GPU,pin_memory=True)

# %%
for head_array,head_center in head_loader:
    plt.figure()
    for ii in range(8):
        plt.subplot(4,2,ii+1)
        plt.imshow(head_array[ii])
    plt.show()
# Out:
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# fku
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# fku
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# (64, 64, 3) 0 255
# ...
